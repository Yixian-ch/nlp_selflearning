# %% [markdown]
# # Tutorial for Craw4AI use
# `https://docs.crawl4ai.com/core/quickstart/`

# %% [markdown]
# ## Generating Markdown
# By default, Crawl4AI automatically generates Markdown from each crawled page. However, the exact output depends on whether you specify a markdown generator or content filter.
# To customize the markdown generators, there has different ways to filter the content, for example the `PruningContentFilter`

# %%
from crawl4ai import AsyncWebCrawler

async with AsyncWebCrawler() as crawler:
    result = await crawler.arun("https://news.ycombinator.com")
    print(type(result))
    print(result.markdown)
# Out:
# [INIT].... → Crawl4AI 0.5.0.post8
# [FETCH]... ↓ https://news.ycombinator.com... | Status: True | Time: 1.20s
# [SCRAPE].. ◆ https://news.ycombinator.com... | Time: 0.091s
# [COMPLETE] ● https://news.ycombinator.com... | Status: True | Total: 1.30s
# <class 'crawl4ai.async_webcrawler.CrawlResultContainer'>
# | [![](https://news.ycombinator.com/y18.svg)](https://news.ycombinator.com) | **[Hacker News](https://news.ycombinator.com/news)** [new](https://news.ycombinator.com/newest) | [past](https://news.ycombinator.com/front) | [comments](https://news.ycombinator.com/newcomments) | [ask](https://news.ycombinator.com/ask) | [show](https://news.ycombinator.com/show) | [jobs](https://news.ycombinator.com/jobs) | [submit](https://news.ycombinator.com/submit) |  [login](https://news.ycombinator.com/login?goto=news)
# ---|---|---
# | 1. | [](https://news.ycombinator.com/vote?id=43734953&how=up&goto=news)| [A Map of British Dialects](https://starkeycomics.com/2023/11/07/map-of-british-english-dialects/) ([starkeycomics.com](https://news.ycombinator.com/from?site=starkeycomics.com))
# ---|---|---
# 85 points by [gregorvand](https://news.ycombinator.com/user?id=gregorvand) [3 hours ago](https://news.ycombinator.com/item?id=43734953) | [hide](https://news.ycombinator.com/hide?id=43734953&goto=news) | [42 comments](https://news.ycombinator.com/item?id=43734953)
# 2. | [](https://news.ycombinator.com/vote?id=43734583&how=up&goto=news)| [Show HN: New world record – verified Goldbach Conjecture up to 4*10^18+7*10^13](https://medium.com/@jay_gridbach/grid-computing-shatters-world-record-for-goldbach-conjecture-verification-1ef3dc58a38d) ([medium.com/jay_gridbach](https://news.ycombinator.com/from?site=medium.com/jay_gridbach))
# 119 points by [jay_gridbach](https://news.ycombinator.com/user?id=jay_gridbach) [4 hours ago](https://news.ycombinator.com/item?id=43734583) | [hide](https://news.ycombinator.com/hide?id=43734583&goto=news) | [54 comments](https://news.ycombinator.com/item?id=43734583)
# 3. | [](https://news.ycombinator.com/vote?id=43734910&how=up&goto=news)| [Show HN: Undercutf1 – F1 Live Timing TUI with Driver Tracker, Variable Delay](https://github.com/JustAman62/undercut-f1) ([github.com/justaman62](https://news.ycombinator.com/from?site=github.com/justaman62))
# 68 points by [deltaknight](https://news.ycombinator.com/user?id=deltaknight) [3 hours ago](https://news.ycombinator.com/item?id=43734910) | [hide](https://news.ycombinator.com/hide?id=43734910&goto=news) | [22 comments](https://news.ycombinator.com/item?id=43734910)
# 4. | [](https://news.ycombinator.com/vote?id=43734795&how=up&goto=news)| [The British sitcom that swept through the Balkans (2023)](https://blog.samizdata.co/p/how-a-british-sitcom-swept-through-the-balkans) ([samizdata.co](https://news.ycombinator.com/from?site=samizdata.co))
# 47 points by [mellosouls](https://news.ycombinator.com/user?id=mellosouls) [4 hours ago](https://news.ycombinator.com/item?id=43734795) | [hide](https://news.ycombinator.com/hide?id=43734795&goto=news) | [34 comments](https://news.ycombinator.com/item?id=43734795)
# 5. | [](https://news.ycombinator.com/vote?id=43731165&how=up&goto=news)| [15,000 lines of verified cryptography now in Python](https://jonathan.protzenko.fr/2025/04/18/python.html) ([protzenko.fr](https://news.ycombinator.com/from?site=protzenko.fr))
# 374 points by [todsacerdoti](https://news.ycombinator.com/user?id=todsacerdoti) [15 hours ago](https://news.ycombinator.com/item?id=43731165) | [hide](https://news.ycombinator.com/hide?id=43731165&goto=news) | [101 comments](https://news.ycombinator.com/item?id=43731165)
# 6. | [](https://news.ycombinator.com/vote?id=43735239&how=up&goto=news)| [Restoring the Galaxian3 Theatre 6, 1992 six player arcade machine](https://philwip.com/2025/04/14/galaxian-3-project-revival/) ([philwip.com](https://news.ycombinator.com/from?site=philwip.com))
# 12 points by [countrymile](https://news.ycombinator.com/user?id=countrymile) [1 hour ago](https://news.ycombinator.com/item?id=43735239) | [hide](https://news.ycombinator.com/hide?id=43735239&goto=news) | [1 comment](https://news.ycombinator.com/item?id=43735239)
# 7. | [](https://news.ycombinator.com/vote?id=43731552&how=up&goto=news)| [Full Text Search of US Court records](https://www.judyrecords.com/) ([judyrecords.com](https://news.ycombinator.com/from?site=judyrecords.com))
# 306 points by [FigurativeVoid](https://news.ycombinator.com/user?id=FigurativeVoid) [14 hours ago](https://news.ycombinator.com/item?id=43731552) | [hide](https://news.ycombinator.com/hide?id=43731552&goto=news) | [56 comments](https://news.ycombinator.com/item?id=43731552)
# 8. | [](https://news.ycombinator.com/vote?id=43712536&how=up&goto=news)| [Peru's ancient irrigation systems turned deserts into farms because of culture](https://theconversation.com/perus-ancient-irrigation-systems-succeeded-in-turning-deserts-into-farms-because-of-the-culture-without-it-the-systems-failed-251199) ([theconversation.com](https://news.ycombinator.com/from?site=theconversation.com))
# 37 points by [PaulHoule](https://news.ycombinator.com/user?id=PaulHoule) [5 hours ago](https://news.ycombinator.com/item?id=43712536) | [hide](https://news.ycombinator.com/hide?id=43712536&goto=news) | [1 comment](https://news.ycombinator.com/item?id=43712536)
# 9. | [](https://news.ycombinator.com/vote?id=43729683&how=up&goto=news)| [Show HN: I made a Doom-like game fit inside a QR code](https://github.com/Kuberwastaken/backdooms) ([github.com/kuberwastaken](https://news.ycombinator.com/from?site=github.com/kuberwastaken))
# 438 points by [kuberwastaken](https://news.ycombinator.com/user?id=kuberwastaken) [18 hours ago](https://news.ycombinator.com/item?id=43729683) | [hide](https://news.ycombinator.com/hide?id=43729683&goto=news) | [121 comments](https://news.ycombinator.com/item?id=43729683)
# 10. | [](https://news.ycombinator.com/vote?id=43705190&how=up&goto=news)| [High time to tackle drug-resistant fungal infections](https://www.nature.com/articles/d41586-025-01177-x) ([nature.com](https://news.ycombinator.com/from?site=nature.com))
# 64 points by [pmags](https://news.ycombinator.com/user?id=pmags) [7 hours ago](https://news.ycombinator.com/item?id=43705190) | [hide](https://news.ycombinator.com/hide?id=43705190&goto=news) | [13 comments](https://news.ycombinator.com/item?id=43705190)
# 11. | [](https://news.ycombinator.com/vote?id=43733636&how=up&goto=news)| [JavaScript Views, the Hard Way – A Pattern for Writing UI](https://github.com/matthewp/views-the-hard-way) ([github.com/matthewp](https://news.ycombinator.com/from?site=github.com/matthewp))
# 101 points by [voat](https://news.ycombinator.com/user?id=voat) [9 hours ago](https://news.ycombinator.com/item?id=43733636) | [hide](https://news.ycombinator.com/hide?id=43733636&goto=news) | [61 comments](https://news.ycombinator.com/item?id=43733636)
# 12. | [](https://news.ycombinator.com/vote?id=43733097&how=up&goto=news)| [Cozy video games can quell stress and anxiety](https://www.reuters.com/business/retail-consumer/cozy-video-games-can-quell-stress-anxiety-2025-01-27/) ([reuters.com](https://news.ycombinator.com/from?site=reuters.com))
# 432 points by [vinhnx](https://news.ycombinator.com/user?id=vinhnx) [10 hours ago](https://news.ycombinator.com/item?id=43733097) | [hide](https://news.ycombinator.com/hide?id=43733097&goto=news) | [252 comments](https://news.ycombinator.com/item?id=43733097)
# 13. | [](https://news.ycombinator.com/vote?id=43691020&how=up&goto=news)| [Understanding the Origins and the Evolution of Vi and Vim](https://pikuma.com/blog/origins-of-vim-text-editor) ([pikuma.com](https://news.ycombinator.com/from?site=pikuma.com))
# 202 points by [amosjyng](https://news.ycombinator.com/user?id=amosjyng) [15 hours ago](https://news.ycombinator.com/item?id=43691020) | [hide](https://news.ycombinator.com/hide?id=43691020&goto=news) | [82 comments](https://news.ycombinator.com/item?id=43691020)
# 14. | [](https://news.ycombinator.com/vote?id=43713159&how=up&goto=news)| [Center Pieces and Lunch Sets in Crochet Work (1915)](https://www.gutenberg.org/cache/epub/75880/pg75880-images.html) ([gutenberg.org](https://news.ycombinator.com/from?site=gutenberg.org))
# 9 points by [petethomas](https://news.ycombinator.com/user?id=petethomas) [3 hours ago](https://news.ycombinator.com/item?id=43713159) | [hide](https://news.ycombinator.com/hide?id=43713159&goto=news) | [1 comment](https://news.ycombinator.com/item?id=43713159)
# 15. | [](https://news.ycombinator.com/vote?id=43708841&how=up&goto=news)| [AI-Designed Antivenoms: New Proteins to Block Deadly Snake Toxins](https://plentyofroom.beehiiv.com/p/antivenoms-with-ai-designed-proteins) ([plentyofroom.beehiiv.com](https://news.ycombinator.com/from?site=plentyofroom.beehiiv.com))
# 51 points by [Lol_arco](https://news.ycombinator.com/user?id=Lol_arco) [9 hours ago](https://news.ycombinator.com/item?id=43708841) | [hide](https://news.ycombinator.com/hide?id=43708841&goto=news) | [8 comments](https://news.ycombinator.com/item?id=43708841)
# 16. | [](https://news.ycombinator.com/vote?id=43692878&how=up&goto=news)| [Ocean Iron Fertilization](https://www.whoi.edu/know-your-ocean/ocean-topics/climate-weather/ocean-based-climate-solutions/iron-fertilization/) ([whoi.edu](https://news.ycombinator.com/from?site=whoi.edu))
# 59 points by [1970-01-01](https://news.ycombinator.com/user?id=1970-01-01) [10 hours ago](https://news.ycombinator.com/item?id=43692878) | [hide](https://news.ycombinator.com/hide?id=43692878&goto=news) | [45 comments](https://news.ycombinator.com/item?id=43692878)
# 17. | [](https://news.ycombinator.com/vote?id=43732805&how=up&goto=news)| [Hypertext TV](https://hypertext.tv/) ([hypertext.tv](https://news.ycombinator.com/from?site=hypertext.tv))
# 171 points by [coloneltcb](https://news.ycombinator.com/user?id=coloneltcb) [11 hours ago](https://news.ycombinator.com/item?id=43732805) | [hide](https://news.ycombinator.com/hide?id=43732805&goto=news) | [20 comments](https://news.ycombinator.com/item?id=43732805)
# 18. | [](https://news.ycombinator.com/vote?id=43733553&how=up&goto=news)| [Hands-On Large Language Models](https://github.com/HandsOnLLM/Hands-On-Large-Language-Models) ([github.com/handsonllm](https://news.ycombinator.com/from?site=github.com/handsonllm))
# 104 points by [teleforce](https://news.ycombinator.com/user?id=teleforce) [9 hours ago](https://news.ycombinator.com/item?id=43733553) | [hide](https://news.ycombinator.com/hide?id=43733553&goto=news) | [7 comments](https://news.ycombinator.com/item?id=43733553)
# 19. | [](https://news.ycombinator.com/vote?id=43714125&how=up&goto=news)| [How the Merchants of Ifriqiya Coded Commerce Before Silicon](https://medium.com/@macvsogjc/the-forgotten-syntax-of-salt-and-gold-how-the-merchants-of-ifriqiya-coded-commerce-before-silicon-d2e8a78e09af) ([medium.com/macvsogjc](https://news.ycombinator.com/from?site=medium.com/macvsogjc))
# 10 points by [thunderbong](https://news.ycombinator.com/user?id=thunderbong) [3 hours ago](https://news.ycombinator.com/item?id=43714125) | [hide](https://news.ycombinator.com/hide?id=43714125&goto=news) | [3 comments](https://news.ycombinator.com/item?id=43714125)
# 20. | [](https://news.ycombinator.com/vote?id=43735170&how=up&goto=news)| [A star appears to have collapsed straight into a black hole without supernova](https://science.nasa.gov/missions/hubble/collapsing-star-gives-birth-to-a-black-hole/) ([nasa.gov](https://news.ycombinator.com/from?site=nasa.gov))
# 25 points by [bfeist](https://news.ycombinator.com/user?id=bfeist) [2 hours ago](https://news.ycombinator.com/item?id=43735170) | [hide](https://news.ycombinator.com/hide?id=43735170&goto=news) | [7 comments](https://news.ycombinator.com/item?id=43735170)
# 21. | [](https://news.ycombinator.com/vote?id=43710996&how=up&goto=news)| [Sponges, drill bits and wires: Surgeons mistakenly left objects inside thousands](https://www.sfchronicle.com/projects/2025/hospitals-surgical-objects-patients/) ([sfchronicle.com](https://news.ycombinator.com/from?site=sfchronicle.com))
# 51 points by [littlexsparkee](https://news.ycombinator.com/user?id=littlexsparkee) [9 hours ago](https://news.ycombinator.com/item?id=43710996) | [hide](https://news.ycombinator.com/hide?id=43710996&goto=news) | [35 comments](https://news.ycombinator.com/item?id=43710996)
# 22. | [](https://news.ycombinator.com/vote?id=43698327&how=up&goto=news)| [Cyberpunk 1958: The Early Days of the Polish IT Industry](https://culture.pl/en/article/cyberpunk-1958-the-early-days-of-the-polish-it-industry) ([culture.pl](https://news.ycombinator.com/from?site=culture.pl))
# 150 points by [StefanBatory](https://news.ycombinator.com/user?id=StefanBatory) [19 hours ago](https://news.ycombinator.com/item?id=43698327) | [hide](https://news.ycombinator.com/hide?id=43698327&goto=news) | [19 comments](https://news.ycombinator.com/item?id=43698327)
# 23. | [](https://news.ycombinator.com/vote?id=43690846&how=up&goto=news)| [Investigating the Luna-Terra Collapse as a Temporal Multilayer Graph](https://dl.acm.org/doi/10.1145/3726869) ([acm.org](https://news.ycombinator.com/from?site=acm.org))
# 22 points by [PaulHoule](https://news.ycombinator.com/user?id=PaulHoule) [6 hours ago](https://news.ycombinator.com/item?id=43690846) | [hide](https://news.ycombinator.com/hide?id=43690846&goto=news) | [5 comments](https://news.ycombinator.com/item?id=43690846)
# 24. | [](https://news.ycombinator.com/vote?id=43698522&how=up&goto=news)| [How a yacht works: sailboat physics and design](https://www.onemetre.net/Design/Design.htm) ([onemetre.net](https://news.ycombinator.com/from?site=onemetre.net))
# 221 points by [stass](https://news.ycombinator.com/user?id=stass) [21 hours ago](https://news.ycombinator.com/item?id=43698522) | [hide](https://news.ycombinator.com/hide?id=43698522&goto=news) | [63 comments](https://news.ycombinator.com/item?id=43698522)
# 25. | [](https://news.ycombinator.com/vote?id=43703998&how=up&goto=news)| [Hydrogen vs. Battery Buses: A European Transit Reality Check](https://cleantechnica.com/2025/04/14/hydrogen-vs-battery-buses-a-european-transit-reality-check/) ([cleantechnica.com](https://news.ycombinator.com/from?site=cleantechnica.com))
# 52 points by [xbmcuser](https://news.ycombinator.com/user?id=xbmcuser) [12 hours ago](https://news.ycombinator.com/item?id=43703998) | [hide](https://news.ycombinator.com/hide?id=43703998&goto=news) | [112 comments](https://news.ycombinator.com/item?id=43703998)
# 26. | [](https://news.ycombinator.com/vote?id=43726051&how=up&goto=news)| [Defold: cross-platform game engine](https://defold.com) ([defold.com](https://news.ycombinator.com/from?site=defold.com))
# 367 points by [xd](https://news.ycombinator.com/user?id=xd) [1 day ago](https://news.ycombinator.com/item?id=43726051) | [hide](https://news.ycombinator.com/hide?id=43726051&goto=news) | [155 comments](https://news.ycombinator.com/item?id=43726051)
# 27. | [](https://news.ycombinator.com/vote?id=43730701&how=up&goto=news)| [There's Life Inside Earth's Crust](https://www.noemamag.com/theres-life-inside-earths-crust/) ([noemamag.com](https://news.ycombinator.com/from?site=noemamag.com))
# 104 points by [jprohov](https://news.ycombinator.com/user?id=jprohov) [16 hours ago](https://news.ycombinator.com/item?id=43730701) | [hide](https://news.ycombinator.com/hide?id=43730701&goto=news) | [32 comments](https://news.ycombinator.com/item?id=43730701)
# 28. | [](https://news.ycombinator.com/vote?id=43731250&how=up&goto=news)| [UML diagram for the DDD example in Evans' book](https://github.com/takaakit/uml-diagram-for-ddd-example-in-evans-book) ([github.com/takaakit](https://news.ycombinator.com/from?site=github.com/takaakit))
# 100 points by [takaakit](https://news.ycombinator.com/user?id=takaakit) [15 hours ago](https://news.ycombinator.com/item?id=43731250) | [hide](https://news.ycombinator.com/hide?id=43731250&goto=news) | [54 comments](https://news.ycombinator.com/item?id=43731250)
# 29. | [](https://news.ycombinator.com/vote?id=43730545&how=up&goto=news)| [Judge Rules Blanket Search of Cell Tower Data Unconstitutional](https://www.404media.co/judge-rules-blanket-search-of-cell-tower-data-unconstitutional/) (edia.co](https://news.ycombinator.com/from?site=404media.co))
# 418 points by [bradac56](https://news.ycombinator.com/user?id=bradac56) [17 hours ago](https://news.ycombinator.com/item?id=43730545) | [hide](https://news.ycombinator.com/hide?id=43730545&goto=news) | [160 comments](https://news.ycombinator.com/item?id=43730545)
# 30. | [](https://news.ycombinator.com/vote?id=43733463&how=up&goto=news)| [System Design of a Cellular APL Computer](https://ieeexplore.ieee.org/document/1671509) ([ieee.org](https://news.ycombinator.com/from?site=ieee.org))
# 30 points by [todsacerdoti](https://news.ycombinator.com/user?id=todsacerdoti) [9 hours ago](https://news.ycombinator.com/item?id=43733463) | [hide](https://news.ycombinator.com/hide?id=43733463&goto=news) | [7 comments](https://news.ycombinator.com/item?id=43733463)
# [More](https://news.ycombinator.com?p=2)
# ![](https://news.ycombinator.com/s.gif) Join us for [_AI Startup School_](https://events.ycombinator.com/ai-sus) this June 16-17 in San Francisco! [Guidelines](https://news.ycombinator.com/newsguidelines.html) | [FAQ](https://news.ycombinator.com/newsfaq.html) | [Lists](https://news.ycombinator.com/lists) | [API](https://github.com/HackerNews/API) | [Security](https://news.ycombinator.com/security.html) | [Legal](https://www.ycombinator.com/legal/) | [Apply to YC](https://www.ycombinator.com/apply/) | Contact Search:

# %%
from crawl4ai import AsyncWebCrawler
##########################################################################
#  configs
from crawl4ai.content_filter_strategy import PruningContentFilter # this method ranks items by their importance from 0 to 1, any item blow the threshold will be cut
from crawl4ai.markdown_generation_strategy import DefaultMarkdownGenerator
from crawl4ai import CacheMode
##########################################################################

# apply configs
from crawl4ai import CrawlerRunConfig


# configs
md_generator = DefaultMarkdownGenerator(
    # how to process the content/response
    content_filter=PruningContentFilter(min_word_threshold=0.3,threshold_type="type")
)


# apply configs
configs = CrawlerRunConfig(
    markdown_generator=md_generator,
    cache_mode=CacheMode.BYPASS # no cache
)

# run crawler
async with AsyncWebCrawler() as crawler:
    response = await crawler.arun("https://news.ycombinator.com", config=configs)
    print(len(response.markdown.raw_markdown))
    print(len(response.markdown.fit_markdown))
# Out:
# [INIT].... → Crawl4AI 0.5.0.post8
# [FETCH]... ↓ https://news.ycombinator.com... | Status: True | Time: 1.36s
# [SCRAPE].. ◆ https://news.ycombinator.com... | Time: 0.176s
# [COMPLETE] ● https://news.ycombinator.com... | Status: True | Total: 1.55s
# 17382
# 10415

# %% [markdown]
# ## Simple data Extraction css-based
# It allows extract structured data like josn usig CSS or XPath selectors
# it supports automatic data extraction with LLM

# %%
#!/usr/bin/env python3

# tools + config tools
from crawl4ai import (
    AsyncWebCrawler,
    BrowserConfig, # 伪装我们的爬虫
    CrawlerRunConfig,
    CacheMode,
    LLMConfig, # parse data config
)

# llm to parse data
from crawl4ai.extraction_strategy import LLMExtractionStrategy

# config our llm
from pydantic import BaseModel, Field

# save data as json
import json

# load API from env
import os

# run asy tool
import asyncio

# handle jupyter issue
import nest_asyncio

# 应用 nest_asyncio 补丁来允许在已有事件循环中运行异步代码
nest_asyncio.apply()

# Create a .env file to add your API in the current dir
from dotenv import load_dotenv
load_dotenv() 

async def main():
    # to use a llm for extraction, some of them need an API key. Here we use deepseek
    api = os.getenv("Deepseek_API")
    provider = "deepseek/deepseek-chat"
    llm_choice = LLMConfig(provider=provider, api_token=api)

    # configs for our LLM: what kind of information need to be extracted, here we will extract topn books from Douban, a chinese online community
    class LLM(BaseModel):
        # structure LLM's searche
        title: str = Field(...,description="书名")
        rank: str = Field(...,description="排名")
        comment: str = Field(...,description="书的简介")


    # configs for llm strategy
    llm_strategy = LLMExtractionStrategy(
        llm_config=llm_choice,
        schema=LLM.model_json_schema(), # method of extraction
        extraction_type="schema",
        verbose=True,
        instruction="请从抓取的内容中提取及其每本书的名字,其排名/评分/简介，并以 JSON 列表形式返回。"
        # extra_arg = {"temperature":0, "max_tokens":n}
    )

    # configs for better crawler
    browser_config = BrowserConfig(headless=True)
    crawler_config = CrawlerRunConfig(
        cache_mode=CacheMode.BYPASS,
        extraction_strategy=llm_strategy,
        page_timeout=3000,
        word_count_threshold=1
    )

    # run our crawler
    async with AsyncWebCrawler(config=browser_config) as crawler:
        for i in range(10):
            result = await crawler.arun(url=f"https://book.douban.com/top250?start={i}", config=crawler_config)

            # read and save data
            json_Data = json.loads(result.extracted_content)
            with open(f"./{i}_page.json","w") as f:
                json.dump(json_Data,f,ensure_ascii=False, indent=4)

asyncio.get_event_loop().run_until_complete(main())
# Out:
# [INIT].... → Crawl4AI 0.5.0.post8
# [FETCH]... ↓ https://book.douban.com/top250?start=0... | Status: True | Time: 2.99s
# [SCRAPE].. ◆ https://book.douban.com/top250?start=0... | Time: 0.062s
# [LOG] Call LLM for https://book.douban.com/top250?start=0 - block index: 0
# [LOG] Extracted 25 blocks from URL: https://book.douban.com/top250?start=0 block index: 0
# [EXTRACT]. ■ Completed for https://book.douban.com/top250?start=0... | Time: 56.607991648999814s
# [COMPLETE] ● https://book.douban.com/top250?start=0... | Status: True | Total: 59.67s
# [FETCH]... ↓ https://book.douban.com/top250?start=1... | Status: True | Time: 1.16s
# [SCRAPE].. ◆ https://book.douban.com/top250?start=1... | Time: 0.057s
# [LOG] Call LLM for https://book.douban.com/top250?start=1 - block index: 0

# %%
# Customization of crawler: BrowserConfig and CrawlerRunConfig
# BrowserConfig: headless(no interface), full UI(with interface), user agent(behave like a user by sending chrome type, os... to avoid being deteceted as webCrawler), JavaScript control
# use example: headless + random UA, host IP

import asyncio
from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig, CacheMode

async def main():
    """
        What is cache: 缓存就是爬虫程序在请求访问一个网站的时候
        会先确认是否有有缓存存在，如果缓存存在且有效，就直接读取本地缓存
        如果有一个条件不满足就正常请求，并且储存缓存,这样子避免重复下载
        爬虫软件的工作流程：发出请求访问服务器，获得响应，解析响应，储存数据，重复这个过程
    """
    # confi
    browser_conf = BrowserConfig(headless=True, user_agent="Mozilla/5.0 (iPhone; CPU iPhone OS 14_7_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.1.2 Mobile/15E148 Safari/604.1")
    run_conf = CrawlerRunConfig(
        cache_mode=CacheMode.BYPASS 
        # decide if save cache or not
    )

    # set up crawler
    async with AsyncWebCrawler(config=browser_conf) as crawler:
        result = await crawler.arun(
            url = "https://book.douban.com/top250",
            config=run_conf
        )
        print(result.markdown)
   

if __name__ == "__main__":
    asyncio.run(main())
